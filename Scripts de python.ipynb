# %% [markdown]
# NewsAPI

# %%
import requests

url = "https://newsapi.org/v2/top-headlines"
params = {
    "country": "us",
    "category": "technology",
    "apiKey": "43bc8d4c74cf4d089bfa2970df75ba62"
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Error:", response.status_code, response.text)

# %% [markdown]
# NewsData.io

# %%
import requests

url = "https://newsdata.io/api/1/news"
params = {
    "apikey": "pub_f1b34d0c1dc54ba794b49a589cebba86",
    "country": "us",
    "category": "science"
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Error:", response.status_code, response.text)

# %% [markdown]
# APITube.io

# %%
import requests

url = "https://api.apitube.io/v1/search"
headers = {
    "Authorization": "Bearer api_live_CzRmMDPXxWKwDc49fI3XW1HVB9X6qm8lsUnowVu9do0TQVsrGBaQ6rbslz"
}
params = {
    "q": "quantum physics",
    "maxResults": 5
}

response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Error:", response.status_code, response.text)

# %% [markdown]
# EODHD

# %%
import requests

symbol = "AAPL.US"
url = f"https://eodhd.com/api/eod/{symbol}"
params = {
    "api_token": "690f6492e73213.87491169",
    "fmt": "json"
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Error:", response.status_code, response.text)
